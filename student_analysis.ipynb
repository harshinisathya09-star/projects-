# %% [markdown]
# <a href="https://colab.research.google.com/github/harshinisathya09-star/projects-/blob/main/student_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/StudentsPerformance.csv")

# %%
print(df.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
print(df.tail())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
print(df.shape)
# Out:
# (1000, 8)

# %%
print(df.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
print(df.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print(df[["math score", "reading score", "writing score"]].describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print("Average Final Grade:", df["writing score"].mean())
# Out:
# Average Final Grade: 68.054

# %%
print("Highest Final Grade:", df["writing score"].max())
# Out:
# Highest Final Grade: 100

# %%
print("Lowest Final Grade:", df["writing score"].min())
# Out:
# Lowest Final Grade: 10

# %%
print("Total Students:", len(df))
# Out:
# Total Students: 1000

# %%
print(df["gender"].value_counts())
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
print(df["parental level of education"].value_counts())
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
print(df["test preparation course"].value_counts())
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df["math score"], bins=10)

plt.title("Distribution of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Number of Students")

plt.show()

# %%
df["gender"].value_counts().plot(kind="bar")

plt.title("Male vs Female Students")
plt.xlabel("Gender")
plt.ylabel("Number of Students")

plt.show()

# %%
df["gender"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.title("Gender Distribution")
plt.ylabel("")

plt.show()

# %%
plt.boxplot(df["math score"])

plt.title("Box Plot of Math Scores")
plt.ylabel("Math Score")

plt.show()

# %%
plt.scatter(df["reading score"], df["writing score"])

plt.title("Reading Score vs Writing Score")
plt.xlabel("Reading Score")
plt.ylabel("Writing Score")

plt.show()

# %%
print(df.corr(numeric_only=True))
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

plt.imshow(corr)

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Matrix")

plt.show()

# %%
df.to_csv("student_performance_processed.csv", index=False)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
In this project, the Student Performance dataset was downloaded from Kaggle, uploaded to Google Colab, and read using the Pandas library. The dataset was explored by displaying the first and last few rows, checking the dataset information, shape, and column names to understand its structure. Missing values and duplicate records were identified and handled to improve the quality of the data. Descriptive statistics such as mean, median, mode, variance, and standard deviation were calculated to understand the performance of students. Outliers were detected and treated using appropriate methods to make the dataset more reliable. A correlation analysis was performed to identify the relationships between different variables affecting student performance. Various visualizations, including bar charts, line charts, histograms, and scatter plots, were created to better understand the distribution of marks and the relationship between different features. Finally, an Exploratory Data Analysis (EDA) summary was prepared to highlight the key findings and insights. This project helped in understanding data cleaning, descriptive statistics, correlation analysis, data visualization, and Exploratory Data Analysis (EDA) using Python, NumPy, Pandas, and Matplotlib.
